# %% [markdown]
# <a href="https://colab.research.google.com/github/bsesethu/JokesGPT/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.cuda.is_available()) # Should return True
# Out:
# True
